# %%
import pandas as pd

# Load the large dataset
df = pd.read_csv('myDataset/refinedFullDataset.csv')

# %%
df=df[['AccentlessSentences','Sentences']]

# %%
df
# Out:
#                                        AccentlessSentences  \
# 0        Những ngay vua qua, tren trang Facebook chinh ...
# 1        Sau do, mot số trang thong tin va mang xã hoi ...
# 2        Truớc thông tin này, ong Doàn Kim Dinh - Chủ t...
# 3        Qua xác minh, khu dat Ngoc Trinh chup hình và ...
# 4        Nhung đây khong phai là dất xay dựng homestay ...
# ...                                                    ...
# 4037325  Để giúp CNVC-LD và nhan dân 6 tỉnh Mien Trung ...
# 4037326  Tại TP Hồ Chi Minh: 43 Hoa Đao, quận Phú Nhuận...
# 4037327  Báo Lao Dong, Quy TLV Lao Đong chan thành cam ...
# 4037328                                         * LĐLD TP.
# 4037329  Ho Chí Minh: 500 triệu đồng * Cty CP Bong đen ...
#
#                                                  Sentences
# 0        Những ngày vừa qua, trên trang Facebook chính ...
# 1        Sau đó, một số trang thông tin và mạng xã hội ...
# 2        Trước thông tin này, ông Đoàn Kim Đình - Chủ t...
# 3        Qua xác minh, khu đất Ngọc Trinh chụp hình và ...
# 4        Nhưng đây không phải là đất xây dựng homestay ...
# ...                                                    ...
# 4037325  Để giúp CNVC-LĐ và nhân dân 6 tỉnh Miền Trung ...
# 4037326  Tại TP Hồ Chí Minh: 43 Hoa Đào, quận Phú Nhuận...
# 4037327  Báo Lao Động, Quỹ TLV Lao Động chân thành cảm ...
# 4037328                                         * LĐLĐ TP.
# 4037329  Hồ Chí Minh: 500 triệu đồng * Cty CP Bóng đèn ...
#
# [4037330 rows x 2 columns]

# %%
# Create a smaller dataset with the first 5000 rows
small_df = df.head(50)

# Save the smaller dataset to a new CSV file
small_df.to_csv('myDataset/hyperSmallDataset.csv', index=False)

# %%
# Create a smaller dataset with the first 5000 rows
small_df = df.head(5000)

# Save the smaller dataset to a new CSV file
small_df.to_csv('myDataset/miniDataset.csv', index=False)

small_df
# Out:
#                                     AccentlessSentences  \
# 0     Những ngay vua qua, tren trang Facebook chinh ...
# 1     Sau do, mot số trang thong tin va mang xã hoi ...
# 2     Truớc thông tin này, ong Doàn Kim Dinh - Chủ t...
# 3     Qua xác minh, khu dat Ngoc Trinh chup hình và ...
# 4     Nhung đây khong phai là dất xay dựng homestay ...
# ...                                                 ...
# 4995  Sau đó quảng cáo thành các dự an dân cu dể rao...
# 4996  Thực te, các khu dất nay nằm xa khu dan cư, kh...
# 4997  Viec tách thửa đất nong nghiệp voi so lưong lo...
# 4998  Ảnh huởng den cac dồ an quy hoach sau nay cung...
# 4999  Truớc tinh trang việc phân lo bán nền trên đia...
#
#                                               Sentences
# 0     Những ngày vừa qua, trên trang Facebook chính ...
# 1     Sau đó, một số trang thông tin và mạng xã hội ...
# 2     Trước thông tin này, ông Đoàn Kim Đình - Chủ t...
# 3     Qua xác minh, khu đất Ngọc Trinh chụp hình và ...
# 4     Nhưng đây không phải là đất xây dựng homestay ...
# ...                                                 ...
# 4995  Sau đó quảng cáo thành các dự án dân cư để rao...
# 4996  Thực tế, các khu đất này nằm xa khu dân cư, kh...
# 4997  Việc tách thửa đất nông nghiệp với số lượng lớ...
# 4998  Ảnh hưởng đến các đồ án quy hoạch sau này cũng...
# 4999  Trước tình trạng việc phân lô bán nền trên địa...
#
# [5000 rows x 2 columns]

# %%
# Create a smaller dataset with the first 5000 rows
small_df = df.head(50000)

# Save the smaller dataset to a new CSV file
small_df.to_csv('myDataset/smallDataset.csv', index=False)

# %%
# Create a smaller dataset with the first 5000 rows
small_df = df.head(500000)

# Save the smaller dataset to a new CSV file
small_df.to_csv('myDataset/mediumDataset.csv', index=False)

# %%
# Create a smaller dataset with the first 5000 rows
small_df = df.head(2000000)

# Save the smaller dataset to a new CSV file
small_df.to_csv('myDataset/bigDataset.csv', index=False)
